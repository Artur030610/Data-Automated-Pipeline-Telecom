# %% [markdown]
# Objetivo: Probar la lógica de limpieza de tiempos negativos y validación de outliers usando .mask() antes de pasarlo al script maestro.
# Autor: José Arturo Pérez Falcón
# Fecha: Febrero 2026

# %%
import pandas as pd

df = pd.read_parquet(r'C:\Users\josperez\Documents\A-DataStack\01-Proyectos\01-Data_PipelinesFibex\02_Data_Lake\gold_data\Silver_PBI_Final.parquet')
df.info()
print(df.describe())
display(df)

""" # 1. Le decimos a Pandas que repita cada fila el número de veces que diga 'Total_Ordenes'
# Esto "descomprime" la tabla de frecuencias de vuelta a la Capa Silver virtualmente
df_prueba = df.loc[df.index.repeat(df['Total_Ordenes'])]

# 2. Ahora sí, le pedimos la mediana real agrupada por Clasificación
display(df_prueba.groupby('Clasificacion')['SLA Resolucion Min'].median())
display(df) """
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133197 entries, 0 to 133196
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   N° Orden            133197 non-null  object
#  1   Quincena Evaluada   133197 non-null  object
#  2   Franquicia          133197 non-null  object
#  3   Clasificacion       133197 non-null  object
#  4   SLA Resolucion Min  133197 non-null  float64
#  5   SLA_Bin             133197 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 6.1+ MB
#        SLA Resolucion Min        SLA_Bin
# count       133197.000000  133197.000000
# mean          1355.432149    1351.047899
# std           3152.603756    3152.534176
# min              1.000000       1.000000
# 25%             83.000000      80.000000
# 50%            194.000000     190.000000
# 75%           1526.000000    1520.000000
# max          65035.000000   65030.000000
#          N° Orden Quincena Evaluada           Franquicia    Clasificacion  \
# 0         V120861       AGO 2025 Q1       FIBEX VALENCIA              NOC
# 1        VC112838       AGO 2025 Q1  FIBEX VILLA DE CURA              NOC
# 2        GU118214       AGO 2025 Q1        FIBEX GUARICO              NOC
# 3         C114940       AGO 2025 Q1        FIBEX CARACAS  MESA DE CONTROL
# 4         V134699       AGO 2025 Q1       FIBEX VALENCIA  MESA DE CONTROL
# ...           ...               ...                  ...              ...
# 133192  MAR168126       FEB 2026 Q1        FIBEX MARIARA  MESA DE CONTROL
# 133193  MAR171435       FEB 2026 Q1        FIBEX MARIARA  MESA DE CONTROL
# 133194  MAR168139       FEB 2026 Q1        FIBEX MARIARA  MESA DE CONTROL
# 133195  LCH339531       FEB 2026 Q1     FIBEX ANZOATEGUI  MESA DE CONTROL
# 133196  MAR173453       FEB 2026 Q1        FIBEX MARIARA  MESA DE CONTROL
#
#         SLA Resolucion Min  SLA_Bin
# 0                     36.0     30.0
# 1                     50.0     50.0
# 2                     22.0     20.0
# 3                      1.0      1.0
# 4                   5522.0   5520.0
# ...                    ...      ...
# 133192              7570.0   7570.0
# 133193              5052.0   5050.0
# 133194              6788.0   6780.0
# 133195                19.0     10.0
# 133196                16.0     10.0
#
# [133197 rows x 6 columns]
# ' # 1. Le decimos a Pandas que repita cada fila el número de veces que diga \'Total_Ordenes\'\n# Esto "descomprime" la tabla de frecuencias de vuelta a la Capa Silver virtualmente\ndf_prueba = df.loc[df.index.repeat(df[\'Total_Ordenes\'])]\n\n# 2. Ahora sí, le pedimos la mediana real agrupada por Clasificación\ndisplay(df_prueba.groupby(\'Clasificacion\')[\'SLA Resolucion Min\'].median())\ndisplay(df) '

# %%
import pandas as pd
df = pd.read_parquet(r'C:\Users\josperez\Documents\A-DataStack\01-Proyectos\01-Data_PipelinesFibex\02_Data_Lake\silver_data\Tickets_Silver_Master.parquet')

display(df)
# Out:
#        Quincena Evaluada FechaInicio   FechaFin      Fecha Apertura  \
# 0            FEB 2026 Q1  2026-01-01 2026-02-15 2026-02-01 15:47:00
# 1            FEB 2026 Q1  2026-01-01 2026-02-15 2026-02-02 08:53:00
# 2            FEB 2026 Q1  2026-01-01 2026-02-15 2026-02-02 11:05:00
# 3            FEB 2026 Q1  2026-01-01 2026-02-15 2026-02-02 14:28:00
# 4            FEB 2026 Q1  2026-01-01 2026-02-15 2026-02-02 16:51:00
# ...                  ...         ...        ...                 ...
# 159796       MAR 2026 Q1  2025-02-01 2026-03-15 2026-03-15 21:27:00
# 159797       MAR 2026 Q1  2025-02-01 2026-03-15 2026-03-15 21:34:00
# 159798       MAR 2026 Q1  2025-02-01 2026-03-15 2026-03-15 21:40:00
# 159799       MAR 2026 Q1  2025-02-01 2026-03-15 2026-03-15 21:46:00
# 159800       MAR 2026 Q1  2025-02-01 2026-03-15 2026-03-15 22:03:00
#
#            Fecha Impresion        Fecha Cierre Fecha Apertura Date  \
# 0      2026-02-01 16:08:00                 NaT          2026-02-01
# 1      2026-02-02 08:53:00                 NaT          2026-02-02
# 2      2026-02-02 13:18:00                 NaT          2026-02-02
# 3      2026-02-02 15:11:00                 NaT          2026-02-02
# 4      2026-02-02 16:52:00                 NaT          2026-02-02
# ...                    ...                 ...                 ...
# 159796 2026-03-15 22:56:00 2026-03-15 22:57:00          2026-03-15
# 159797 2026-03-15 23:04:00 2026-03-15 23:08:00          2026-03-15
# 159798 2026-03-15 23:22:00 2026-03-15 23:24:00          2026-03-15
# 159799 2026-03-15 23:32:00 2026-03-15 23:33:00          2026-03-15
# 159800 2026-03-15 23:46:00 2026-03-15 23:49:00          2026-03-15
#
#        Fecha Cierre Date  Es_Falla  Cumplio_SLA  ...  N° Contrato   N° Orden  \
# 0                    NaT         1            0  ...     LCH36432  LCH266825
# 1                    NaT         1            0  ...      POR1000    POR6526
# 2                    NaT         1            0  ...     LCH28349  LCH267102
# 3                    NaT         1            0  ...      MI12816   MI175460
# 4                    NaT         1            0  ...      MI13453   MI175477
# ...                  ...       ...          ...  ...          ...        ...
# 159796        2026-03-15         1            1  ...     LCH79346  LCH426987
# 159797        2026-03-15         1            1  ...       C52335    C281364
# 159798        2026-03-15         1            1  ...      GU15371   GU342891
# 159799        2026-03-15         1            1  ...     LCH16846  LCH426998
# 159800        2026-03-15         1            1  ...        H4899    V498378
#
#         Estatus contrato  Estatus_orden Usuario Final Usuario Emisión  \
# 0                 ACTIVO        IMPRESA          None      APICONEXVE
# 1                 ACTIVO        IMPRESA          None      YOMARTINEZ
# 2                 ACTIVO        IMPRESA          None     KABELISARIO
# 3                 ACTIVO        IMPRESA          None          GJASPE
# 4                 ACTIVO        IMPRESA          None         JLUQUEZ
# ...                  ...            ...           ...             ...
# 159796            ACTIVO     FINALIZADA       FRPARRA      APICONEXVE
# 159797            ACTIVO     FINALIZADA       FRPARRA      APICONEXVE
# 159798            ACTIVO     FINALIZADA       FRPARRA      APICONEXVE
# 159799            ACTIVO     FINALIZADA       FRPARRA      APICONEXVE
# 159800            ACTIVO     FINALIZADA         FLEAL      APICONEXVE
#
#        Usuario Impresión        Solucion Aplicada  \
# 0                  FLEAL                     None
# 1             YOMARTINEZ                     None
# 2                  KUSEA                     None
# 3             ANTJIMENEZ                     None
# 4                JLUQUEZ                     None
# ...                  ...                      ...
# 159796           FRPARRA               DNS ERRADO
# 159797           FRPARRA           CAMBIO DE VLAN
# 159798           FRPARRA       ONT DESCONFIGURADA
# 159799           FRPARRA  FALLA EN LA RED INTERNA
# 159800             FLEAL         REINICIAR EQUIPO
#
#                        Detalle Orden SLA Detalle Texto
# 0       NO NAVEGA EN CIERTAS PAGINAS              None
# 1                          FALLA LOS              None
# 2                       SIN INTERNET              None
# 3                          FALLA LOS              None
# 4                          FALLA LOS              None
# ...                              ...               ...
# 159796                INTERNET LENTO   0 days 01:30:00
# 159797                INTERNET LENTO   0 days 01:34:00
# 159798                  SIN INTERNET   0 days 01:44:00
# 159799                  SIN INTERNET   0 days 01:47:00
# 159800                INTERNET LENTO   0 days 01:46:00
#
# [159801 rows x 28 columns]

# %%
import pandas as pd
df = pd.read_parquet(r'C:\Users\josperez\Documents\A-DataStack\01-Proyectos\01-Data_PipelinesFibex\02_Data_Lake\gold_data\SLA_Gold.parquet')
print(df.columns)
mask_march = (df['Quincena Evaluada'].str.contains('MAR', case=False, na=False))
df = df[mask_march]
df = df.groupby('Clasificacion').agg({'SLA Resolucion Min': 'size'}).reset_index()
display(df)
# Out:
# Index(['Quincena Evaluada', 'Franquicia', 'Clasificacion',
#        'Fecha Apertura Date', 'Total_Ordenes', 'SLA Resolucion Min',
#        'SLA Despacho Min', 'SLA Impresion Min'],
#       dtype='object')
#      Clasificacion  SLA Resolucion Min
# 0  MESA DE CONTROL                 671
# 1              NOC                 292
# 2      OPERACIONES                  41
