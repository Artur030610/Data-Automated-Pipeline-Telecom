# %%
import pandas as pd

df = pd.read_parquet(r"c:\Users\josperez\Documents\A-DataStack\01-Proyectos\01-Data_PipelinesFibex\02_Data_Lake\gold_data\UAbonados_Gold.parquet")
display(df)
# Out:
#                             ID N° Abonado Documento  \
# 0       'CONTFF7002ACCEC43838'      T1965  31281196
# 1       'CONTB76FA1259AF06471'     V97202  13956779
# 2       'CONTFFE753225FA48013'     C28264  23634391
# 3       'CONTC7B204366AF12595'    MAR0100  20243186
# 4       'CONTA517B6F009923500'      T8427  16773921
# ...                        ...        ...       ...
# 686505  'CONTF4539E8AFF649014'     MI6571  27037288
# 686506  'CONTF453BC5C7E253028'     SR1486  20268910
# 686507  'CONTF453EC5A25E04910'     C27709  19399461
# 686508  'CONTF4540E6BAFC74992'    LG20077  19593330
# 686509  'CONTF4542AE7A3865340'      V1690   7103110
#
#                                    Cliente       Fecha Contrato      Estatus  \
# 0                MAIKER JOSE LOPEZ MENDOZA  2023-09-11 00:00:00       ACTIVO
# 1           NELSON FIDEL ESCALONA OLIVEROS  2025-02-20 00:00:00       ACTIVO
# 2         NAYLIT MERCEDES MONTES FUENMAYOR  2024-10-04 00:00:00       ACTIVO
# ...

# %%
df2 = pd.read_parquet(r"C:\Users\josperez\Documents\A-DataStack\01-Proyectos\01-Data_PipelinesFibex\02_Data_Lake\gold_data\Dim_Cliente.parquet")
display(df2)
# Out:
#         Cliente_SK                      ID  \
# 0                1  'CONT70DBA2F009C33647'
# 1                2  'CONT71B2C8A830782206'
# 2                3  'CONT3054B0A13FC36757'
# 3                4  'CONT3EDE9BEC8DA31581'
# 4                5  'CONT87183D9F88B52696'
# ...            ...                     ...
# 716166      730187  'CONTF60C769763771713'
# 716167      730188  'CONTF61A747E03548744'
# 716168      730189  'CONTF627EA8C8CB31666'
# 716169      730190  'CONTF63EAF3D9A749696'
# 716170      730191  'CONTF673DAE5AFE96506'
#
#                                       Cliente Fecha Contrato  \
# 0                  LENDYS YOHARY CAMPOS LOPEZ     2023-12-06
# 1                  JOSE EDUARDO  ARRAIZ LOPEZ     2023-12-07
# 2         ALEJANDRA DEL CARMEN  NÚÑEZ JIMÉNEZ     2025-05-23
# 3                                   GENY DAZA     2022-10-06
# 4                MARIA VALENTINA MEALHA SOUSA     2021-04-26
# ...                                       ...            ...
# ...
